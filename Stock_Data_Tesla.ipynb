# %% [markdown]
# # Stock Data - Tesla (TSLA)

# %% [markdown]
# ### This workbook is used to pull stock data using the yfinance package.

# %%
# Import yfinance package
import yfinance as yf

# %%
# Declare company ticker
ticker = "TSLA"

# %%
# Retrieve 7 day stock price on an hourly basis
hourly_hist = yf.download(ticker, period="252d", interval="60m")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
hourly_hist.head(50)
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2019-10-17 09:30:00-04:00  52.500000  52.951000  52.180000  52.314003
# 2019-10-17 10:30:00-04:00  52.296001  52.388000  52.096001  52.309998
# 2019-10-17 11:30:00-04:00  52.299999  52.446003  52.112000  52.409004
# 2019-10-17 12:30:00-04:00  52.405998  52.534004  52.252003  52.426003
# 2019-10-17 13:30:00-04:00  52.421837  52.434002  52.241997  52.382000
# 2019-10-17 14:30:00-04:00  52.375122  52.447998  52.194000  52.296001
# 2019-10-17 15:30:00-04:00  52.290001  52.400002  52.247997  52.396004
# 2019-10-18 09:30:00-04:00  52.200001  52.471996  51.740002  51.896004
# 2019-10-18 10:30:00-04:00  51.900002  52.046001  51.632000  51.855621
# 2019-10-18 11:30:00-04:00  51.855999  51.885303  51.038002  51.146000
# 2019-10-18 12:30:00-04:00  51.139999  51.471996  51.020000  51.378002
# 2019-10-18 13:30:00-04:00  51.391998  51.523998  51.223999  51.378620
# ...

# %%
# convert hourly trade data to CSV

hourly_hist.to_csv('Hourly_trading_data')

# %%
# pull 2 years of daily trading history

daily_df = tickerData.history(period='1d', start='2016-1-1')

# %%
daily_df.tail()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2020-10-09  430.130005  434.589996  426.459991  434.000000  28925700
# 2020-10-12  442.000000  448.739990  438.579987  442.299988  38791100
# 2020-10-13  443.350006  448.890015  436.600006  446.649994  34463700
# 2020-10-14  449.779999  465.899994  447.350006  461.299988  48045400
# 2020-10-15  450.309998  456.570007  442.500000  448.880005  35554200
#
#             Dividends  Stock Splits
# Date
# 2020-10-09          0           0.0
# 2020-10-12          0           0.0
# 2020-10-13          0           0.0
# 2020-10-14          0           0.0
# 2020-10-15          0           0.0

# %%
daily_df.to_csv('Daily_Stock_Data_4_Yrs.csv')

# %%
fifteen_min_hist = yf.download(ticker, period="60d", interval="15m")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fifteen_min_hist.to_csv('Fifteen_Min_Stock_Data')
